# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"

df = pd.read_csv(url)

df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(df['rm'])

plt.title("Distribution of Number of Rooms")

plt.xlabel("Rooms")

plt.ylabel("Frequency")

plt.show()

# %%
plt.scatter(df['rm'], df['medv'])

plt.title("Rooms vs House Value")

plt.xlabel("Number of Rooms")

plt.ylabel("Median House Value")

plt.show()

# %%
correlation = df['rm'].corr(df['medv'])

print("Correlation:", correlation)
# Out:
# Correlation: 0.6953599470715393

# %%
print(locals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'correlation = df[\'rm\'].corr(df[\'medv\'])\n\nprint("Correlation:", correlation)', 'import seaborn as sns\nimport matplotlib.pyplot as plt\n\nplt.figure(figsize=(10,8))\n\nsns.heatmap(df.corr(), annot=True, cmap=\'coolwarm\')\n\nplt.title("Correlation Heatmap")\n\nplt.show()', 'import seaborn as sns\nimport matplotlib.pyplot as plt\n\nplt.figure(figsize=(10,8))\n\nsns.heatmap(df.corr(), annot=True, cmap=\'coolwarm\')\n\nplt.title("Correlation Heatmap")\n\nplt.show()', 'print(locals())'], '_oh': {}, '_dh': ['/content'], 'In': ['', 'correlation = df[\'rm\'].corr(df[\'medv\'])\n\nprint("Correlation:", correlation)', 'import seaborn as sns\nimport matplotlib.pyplot as plt\n\nplt.figure(figsize=(10,8))\n\nsns.heatmap(df.c
# ...

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"

df = pd.read_csv(url)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap")

plt.show()

# %%
sns.regplot(x='rm', y='medv', data=df)

plt.title("Rooms vs House Value")

plt.xlabel("Number of Rooms")

plt.ylabel("Median House Value")

plt.show()

# %%
correlations = df.corr()['medv'].sort_values(ascending=False)

print(correlations)
# Out:
# medv       1.000000
# rm         0.695360
# zn         0.360445
# b          0.333461
# dis        0.249929
# chas       0.175260
# age       -0.376955
# rad       -0.381626
# crim      -0.388305
# nox       -0.427321
# tax       -0.468536
# indus     -0.483725
# ptratio   -0.507787
# lstat     -0.737663
# Name: medv, dtype: float64

# %% [markdown]
# # Housing Data Analysis Findings
#
# ## Key Insights
#
# - Most houses contain between 5 and 7 rooms.
# - Houses with more rooms generally have higher values.
# - The variable "rm" showed a strong positive correlation with house value.
# - The variable "lstat" showed the strongest negative correlation with house value.
# - Several outliers were identified in the scatter plots.
#
# ## Conclusion
#
#  The house size and neighborhood characteristics strongly influence housing prices.
